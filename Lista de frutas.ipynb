# %% [markdown]
# #Coleções - LISTAS
#
# Coleções de objetos variados e repetitivos, não ordenada, Mutável.

# %%
a = []
b = [1,2,3,4,5,6,7,8]
c = ["Frutas", 12, "Tennis",3.14]

for i in b:
    print("Elemento" ,i)


Frutas = ["Banana", "Maçã", "Laranja", "Abacaxi", "Uva"]
print("==============================================")
print("Inserir Manga na ultima posição")
print("")
Frutas.append("Manga")
print(Frutas)
print("==============================================")
print("")
print("Inserir Melancia na posição 2")
print("")
Frutas.insert(2, "Melancia")
print(Frutas)
print("==============================================")
print("Remove o abacaxi")
print("")
Frutas.remove("Abacaxi")
print(Frutas)

print("")
Frutas.sort()
print("==============================================")
print("Ordenar a lista")
print("")   

print(Frutas[2])
print("==============================================")
print("Imprime o elemento da posição 2")    

print("")
FrutasComprar = Frutas
FrutasComprar.append("Pera")
print("")
print(FrutasComprar)
# Out:
# Elemento 1
# Elemento 2
# Elemento 3
# Elemento 4
# Elemento 5
# Elemento 6
# Elemento 7
# Elemento 8
# ...
# Inserir Manga na ultima posição
#
# ['Banana', 'Maçã', 'Laranja', 'Abacaxi', 'Uva', 'Manga']
# ...
#
# Inserir Melancia na posição 2
#
# ['Banana', 'Maçã', 'Melancia', 'Laranja', 'Abacaxi', 'Uva', 'Manga']
# ...
# Remove o abacaxi
#
# ['Banana', 'Maçã', 'Melancia', 'Laranja', 'Uva', 'Manga']
#
# ...
# Ordenar a lista
#
# Manga
# ...
# Imprime o elemento da posição 2
#
#
# ['Banana', 'Laranja', 'Manga', 'Maçã', 'Melancia', 'Uva', 'Pera']

# %%
FrutasComprar = Frutas[:]
FrutasComprar.append("Limão")
print("Lista de frutas: ",FrutasComprar)
print("Lista de frutas: ",Frutas)
print("")
print(Frutas.index("Pera"))
print(Frutas.index("Maçã"))
print("")

print(Frutas.count("Maçã"))
# Out:
# Lista de frutas:  ['Banana', 'Laranja', 'Manga', 'Maçã', 'Melancia', 'Uva', 'Pera', 'Limão']
# Lista de frutas:  ['Banana', 'Laranja', 'Manga', 'Maçã', 'Melancia', 'Uva', 'Pera']
#
# 6
# 3
#
# 1
